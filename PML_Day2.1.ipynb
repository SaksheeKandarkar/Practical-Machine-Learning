# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("C:\CDAC\ML\Topic 2\data_MR_2.csv")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 53940 entries, 0 to 53939
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   cut     53940 non-null  object
#  1   x       53940 non-null  float64
#  2   y       53940 non-null  float64
#  3   z       53940 non-null  float64
# dtypes: float64(3), object(1)
# memory usage: 1.6+ MB

# %%
df
# Out:
#              cut     x     y     z
# 0          Ideal  3.95  3.98  2.43
# 1        Premium  3.89  3.84  2.31
# 2           Good  4.05  4.07  2.31
# 3        Premium  4.20  4.23  2.63
# 4           Good  4.34  4.35  2.75
# ...          ...   ...   ...   ...
# 53935      Ideal  5.75  5.76  3.50
# 53936       Good  5.69  5.75  3.61
# 53937  Very Good  5.66  5.68  3.56
# 53938    Premium  6.15  6.12  3.74
# 53939      Ideal  5.83  5.87  3.64
#
# [53940 rows x 4 columns]

# %%
df.drop_duplicates(inplace=True)

# %%
df.shape
# Out:
# (42907, 4)

# %%
df
# Out:
#              cut     x     y     z
# 0          Ideal  3.95  3.98  2.43
# 1        Premium  3.89  3.84  2.31
# 2           Good  4.05  4.07  2.31
# 3        Premium  4.20  4.23  2.63
# 4           Good  4.34  4.35  2.75
# ...          ...   ...   ...   ...
# 53931    Premium  5.74  5.73  3.43
# 53932  Very Good  5.71  5.76  3.47
# 53935      Ideal  5.75  5.76  3.50
# 53936       Good  5.69  5.75  3.61
# 53938    Premium  6.15  6.12  3.74
#
# [42907 rows x 4 columns]

# %%
df.isna().sum()
# Out:
# cut    0
# x      0
# y      0
# z      0
# dtype: int64

# %% [markdown]
# # Label Encoding cut column

# %%
df['cut'].unique()
# Out:
# array(['Ideal', 'Premium', 'Good', 'Very Good', 'Fair'], dtype=object)

# %%
labels_map={'cut':{'Ideal':5, 'Premium':4, 'Good':2, 'Very Good':3, 'Fair':1}}

# %%
df.replace(labels_map,inplace=True)
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_15108\2349197014.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df.replace(labels_map,inplace=True)

# %%
from sklearn import cluster.KMeans

# %%
X=df

# %%
X_train,X_test = train_test_split(X, test_size=0.3,random_state=9)

# %%
km=cluster.KMeans()

# %%
km.fit(X_train)
# Out:
# KMeans()

# %%
ypred=km.predict(X_test)
