# %%
import pandas as pd
df = pd.read_csv(r"C:\CDAC\ML\Topic13\Pytorch\sonar.csv")
df.shape
# Out:
# (208, 61)

# %%
df.columns
# Out:
# Index(['V1', 'V2', 'V3', 'V4', 'V5', 'V6', 'V7', 'V8', 'V9', 'V10', 'V11',
#        'V12', 'V13', 'V14', 'V15', 'V16', 'V17', 'V18', 'V19', 'V20', 'V21',
#        'V22', 'V23', 'V24', 'V25', 'V26', 'V27', 'V28', 'V29', 'V30', 'V31',
#        'V32', 'V33', 'V34', 'V35', 'V36', 'V37', 'V38', 'V39', 'V40', 'V41',
#        'V42', 'V43', 'V44', 'V45', 'V46', 'V47', 'V48', 'V49', 'V50', 'V51',
#        'V52', 'V53', 'V54', 'V55', 'V56', 'V57', 'V58', 'V59', 'V60', 'Class'],
#       dtype='object')

# %%
X = df.drop('Class',axis=1)
y = df['Class']

# %%
X.shape,y.shape
# Out:
# ((208, 60), (208,))

# %%
y.unique() # R means Rock, M means Mine
# Out:
# array(['R', 'M'], dtype=object)

# %%
y = y.replace({'R':0,'M':1})
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_20916\3092005575.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   y = y.replace({'R':0,'M':1})

# %%
y.unique(), y.dtype
# Out:
# (array([0, 1], dtype=int64), dtype('int64'))

# %%
y.value_counts(normalize=True)
# Out:
# Class
# 1    0.533654
# 0    0.466346
# Name: proportion, dtype: float64

# %%
#pip install torch

# %%
import torch
import torch.nn as nn
import torch.optim as optim

# %%
X = torch.tensor(X.values, dtype=torch.float32)
y = torch.tensor(y.values, dtype=torch.float32).reshape(-1, 1)

# %%
X.shape,y.shape
# Out:
# (torch.Size([208, 60]), torch.Size([208, 1]))

# %%
input_size = X.shape[1]

# %%
# define the model
model = nn.Sequential(
    nn.Linear(input_size, 12), # HL1 all columns in X as inputs and 12 neuron so 12 output
    nn.ReLU(), # activation function layer for HL1
    nn.Linear(12, 8), # HL2 12 inputs and 8 neuron so 8 output
    nn.ReLU(),# activation function layer for HL2
    nn.Linear(8, 1),# output layer 9 inputs and 1 neuron so 1 output
    nn.Sigmoid()# activation function layer for output layer
)
print(model)
# Out:
# Sequential(
#   (0): Linear(in_features=60, out_features=12, bias=True)
#   (1): ReLU()
#   (2): Linear(in_features=12, out_features=8, bias=True)
#   (3): ReLU()
#   (4): Linear(in_features=8, out_features=1, bias=True)
#   (5): Sigmoid()
# )

# %%
# Define loss function
loss_fn   = nn.BCELoss()  # binary cross entropy

# %%
# define optimizer for weights and bias of model (model.parameters)
optimizer = optim.Adam(model.parameters(), lr=0.001)

# %%
# define epoch and batch size
n_epochs = 100
batch_size = 10

# %%
for epoch in range(n_epochs):
    for i in range(0, len(X), batch_size):
        # forward pass
        Xbatch = X[i:i+batch_size]
        y_pred = model(Xbatch)
        ybatch = y[i:i+batch_size]
        loss = loss_fn(y_pred, ybatch )
        # back propagation
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
    print(f'Finished epoch {epoch}, latest loss {loss}')
# Out:
# Finished epoch 0, latest loss 0.5858358144760132
# Finished epoch 1, latest loss 0.5870842933654785
# Finished epoch 2, latest loss 0.5871045589447021
# Finished epoch 3, latest loss 0.586441695690155
# Finished epoch 4, latest loss 0.5859569311141968
# Finished epoch 5, latest loss 0.5859471559524536
# Finished epoch 6, latest loss 0.584881067276001
# Finished epoch 7, latest loss 0.5821514129638672
# Finished epoch 8, latest loss 0.5789374113082886
# Finished epoch 9, latest loss 0.576267421245575
# Finished epoch 10, latest loss 0.5741056799888611
# Finished epoch 11, latest loss 0.5722123384475708
# Finished epoch 12, latest loss 0.5696106553077698
# Finished epoch 13, latest loss 0.5675424337387085
# Finished epoch 14, latest loss 0.5647433400154114
# Finished epoch 15, latest loss 0.5627411007881165
# Finished epoch 16, latest loss 0.5616397857666016
# Finished epoch 17, latest loss 0.5596567392349243
# Finished epoch 18, latest loss 0.5583813190460205
# Finished epoch 19, latest loss 0.5565983057022095
# Finished epoch 20, latest loss 0.5556488037109375
# Finished epoch 21, latest loss 0.5548089742660522
# Finished epoch 22, latest loss 0.5539778470993042
# Finished epoch 23, latest loss 0.5527219176292419
# Finished epoch 24, latest loss 0.5517403483390808
# Finished epoch 25, latest loss 0.5501194596290588
# Finished epoch 26, latest loss 0.5485832691192627
# Finished epoch 27, latest loss 0.5469259023666382
# Finished epoch 28, latest loss 0.5444397926330566
# Finished epoch 29, latest loss 0.5424759387969971
# Finished epoch 30, latest loss 0.5404539108276367
# Finished epoch 31, latest loss 0.5380299687385559
# Finished epoch 32, latest loss 0.5353479385375977
# Finished epoch 33, latest loss 0.531682550907135
# Finished epoch 34, latest loss 0.5275470614433289
# Finished epoch 35, latest loss 0.5257095098495483
# Finished epoch 36, latest loss 0.5230951309204102
# Finished epoch 37, latest loss 0.5230958461761475
# Finished epoch 38, latest loss 0.5185799598693848
# Finished epoch 39, latest loss 0.5139572024345398
# Finished epoch 40, latest loss 0.5065300464630127
# Finished epoch 41, latest loss 0.5041951537132263
# Finished epoch 42, latest loss 0.497450053691864
# Finished epoch 43, latest loss 0.4939185380935669
# Finished epoch 44, latest loss 0.4853143095970154
# Finished epoch 45, latest loss 0.4819984436035156
# Finished epoch 46, latest loss 0.47099512815475464
# Finished epoch 47, latest loss 0.47090867161750793
# Finished epoch 48, latest loss 0.4589863419532776
# Finished epoch 49, latest loss 0.45155537128448486
# Finished epoch 50, latest loss 0.4396081268787384
# Finished epoch 51, latest loss 0.43292611837387085
# Finished epoch 52, latest loss 0.4171840250492096
# Finished epoch 53, latest loss 0.41454529762268066
# Finished epoch 54, latest loss 0.39648154377937317
# Finished epoch 55, latest loss 0.39025866985321045
# Finished epoch 56, latest loss 0.37702709436416626
# Finished epoch 57, latest loss 0.37137284874916077
# Finished epoch 58, latest loss 0.35666623711586
# Finished epoch 59, latest loss 0.349821537733078
# Finished epoch 60, latest loss 0.3364146053791046
# Finished epoch 61, latest loss 0.32911452651023865
# Finished epoch 62, latest loss 0.3206489086151123
# Finished epoch 63, latest loss 0.31069105863571167
# Finished epoch 64, latest loss 0.3030838966369629
# Finished epoch 65, latest loss 0.2925257384777069
# Finished epoch 66, latest loss 0.2861884832382202
# Finished epoch 67, latest loss 0.277040958404541
# Finished epoch 68, latest loss 0.2686205208301544
# Finished epoch 69, latest loss 0.25999096035957336
# Finished epoch 70, latest loss 0.2531464099884033
# Finished epoch 71, latest loss 0.24598613381385803
# Finished epoch 72, latest loss 0.24067793786525726
# Finished epoch 73, latest loss 0.23235546052455902
# Finished epoch 74, latest loss 0.22606053948402405
# Finished epoch 75, latest loss 0.22007371485233307
# Finished epoch 76, latest loss 0.21351635456085205
# Finished epoch 77, latest loss 0.20818369090557098
# Finished epoch 78, latest loss 0.20199702680110931
# Finished epoch 79, latest loss 0.19777090847492218
# Finished epoch 80, latest loss 0.1921531856060028
# Finished epoch 81, latest loss 0.18600767850875854
# Finished epoch 82, latest loss 0.17871853709220886
# Finished epoch 83, latest loss 0.17531880736351013
# Finished epoch 84, latest loss 0.17217335104942322
# Finished epoch 85, latest loss 0.16452080011367798
# Finished epoch 86, latest loss 0.16211530566215515
# Finished epoch 87, latest loss 0.15653254091739655
# Finished epoch 88, latest loss 0.15323692560195923
# Finished epoch 89, latest loss 0.1481241136789322
# Finished epoch 90, latest loss 0.14521567523479462
# Finished epoch 91, latest loss 0.1423262655735016
# Finished epoch 92, latest loss 0.13843832910060883
# Finished epoch 93, latest loss 0.13579368591308594
# Finished epoch 94, latest loss 0.13241252303123474
# Finished epoch 95, latest loss 0.12769991159439087
# Finished epoch 96, latest loss 0.12568487226963043
# Finished epoch 97, latest loss 0.12017452716827393
# Finished epoch 98, latest loss 0.11867489665746689
# Finished epoch 99, latest loss 0.11590825766324997

# %%
# compute accuracy (no_grad is optional)
with torch.no_grad():
    y_pred = model(X)
accuracy = (y_pred.round() == y).float().mean() #2.5 round to 2, 2.3 to 2, 2.9 to 3
print(f"Accuracy {accuracy}")
# Out:
# Accuracy 0.8894230723381042
